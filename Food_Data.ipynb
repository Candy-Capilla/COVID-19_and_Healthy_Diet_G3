# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
csv_file = "Resources/Food_Supply_kcal_Data.csv"
food_supply_df = pd.read_csv(csv_file)
food_df= food_supply_df[food_supply_df.columns[:-8]].set_index('Country')
food_df
# Out:
#                                     Alcoholic Beverages  Animal Products  \
# Country
# Afghanistan                                      0.0000           4.7774
# Albania                                          0.9120          16.0930
# Algeria                                          0.0896           6.0326
# Angola                                           1.9388           4.6927
# Antigua and Barbuda                              2.3041          15.3672
# ...                                                 ...              ...
# Venezuela (Bolivarian Republic of)               0.8454           7.2303
# Vietnam                                          0.7150          10.9806
# Yemen                                            0.0000           3.4667
# Zambia                                           1.1925           3.3043
# Zimbabwe                                         1.4269           3.9356
#
#                                     Animal fats  Aquatic Products, Other  \
# Country
# Afghanistan                              0.8504                      0.0
# Albania                                  1.0591                      0.0
# Algeria                                  0.1941                      0.0
# Angola                                   0.2644                      0.0
# Antigua and Barbuda                      1.5429                      0.0
# ...                                         ...                      ...
# Venezuela (Bolivarian Republic of)       0.6007                      0.0
# Vietnam                                  0.9363                      0.0
# Yemen                                    0.3394                      0.0
# Zambia                                   0.3230                      0.0
# Zimbabwe                                 0.6904                      0.0
#
#                                     Cereals - Excluding Beer    Eggs  \
# Country
# Afghanistan                                          37.1186  0.1501
# Albania                                              16.2107  0.8091
# Algeria                                              25.0112  0.4181
# Angola                                               18.3521  0.0441
# Antigua and Barbuda                                  13.7215  0.2057
# ...                                                      ...     ...
# Venezuela (Bolivarian Republic of)                   21.3126  0.2892
# Vietnam                                              26.9833  0.2894
# Yemen                                                32.0727  0.1455
# Zambia                                               31.5528  0.1988
# Zimbabwe                                             29.8044  0.1381
#
#                                     Fish, Seafood  Fruits - Excluding Wine  \
# Country
# Afghanistan                                0.0000                   1.4757
# Albania                                    0.1471                   3.8982
# Algeria                                    0.1195                   3.1805
# Angola                                     0.8372                   2.3133
# Antigua and Barbuda                        1.7280                   3.6824
# ...                                           ...                      ...
# Venezuela (Bolivarian Republic of)         0.4449                   2.3804
# Vietnam                                    1.0385                   1.8046
# Yemen                                      0.1697                   1.1879
# Zambia                                     0.5714                   0.2236
# Zimbabwe                                   0.1611                   0.4373
#
#                                       Meat  Milk - Excluding Butter  ...  \
# Country                                                              ...
# Afghanistan                         1.2006                   2.4512  ...
# Albania                             3.8688                   9.9441  ...
# Algeria                             1.2543                   3.9869  ...
# Angola                              2.9302                   0.5067  ...
# Antigua and Barbuda                 7.0356                   4.6904  ...
# ...                                    ...                      ...  ...
# Venezuela (Bolivarian Republic of)  3.1368                   2.6474  ...
# Vietnam                             7.8311                   0.5618  ...
# Yemen                               2.0121                   0.6545  ...
# Zambia                              1.5155                   0.5217  ...
# Zimbabwe                            1.7491                   1.0817  ...
#
#                                     Pulses  Spices  Starchy Roots  Stimulants  \
# Country
# Afghanistan                         0.5003  0.1001         0.3252      0.0750
# Albania                             0.8091  0.0000         1.2651      0.2501
# Algeria                             1.0900  0.1195         1.9262      0.1493
# Angola                              1.4981  0.0000        12.6239      0.0441
# Antigua and Barbuda                 0.4526  0.3497         0.8434      0.4937
# ...                                    ...     ...            ...         ...
# Venezuela (Bolivarian Republic of)  0.7341  0.0000         1.3571      0.0667
# Vietnam                             0.4597  0.4256         0.7150      0.1021
# Yemen                               1.2121  0.0485         0.3152      0.1212
# Zambia                              0.2981  0.0745         4.0994      0.0248
# Zimbabwe                            0.6214  0.0460         1.2888      0.0460
#
#                                     Sugar Crops  Sugar & Sweeteners  Treenuts  \
# Country
# Afghanistan                              0.0000              2.2261    0.1251
# Albania                                  0.0000              3.4422    0.3972
# Algeria                                  0.0000              3.9869    0.2240
# Angola                                   0.0000              2.7539    0.0000
# Antigua and Barbuda                      0.0000              5.8218    0.0823
# ...                                         ...                 ...       ...
# Venezuela (Bolivarian Republic of)       0.0000              7.7864    0.0000
# Vietnam                                  0.1532              2.0940    0.3575
# Yemen                                    0.0000              7.0303    0.0242
# Zambia                                   0.0000              2.5590    0.0000
# Zimbabwe                                 0.0000              5.0403    0.1151
#
#                                     Vegetal Products  Vegetable Oils  \
# Country
# Afghanistan                                  45.2476          2.3012
# Albania                                      33.9070          2.8244
# Algeria                                      43.9749          5.7638
# Angola                                       45.3184          4.2741
# Antigua and Barbuda                          34.6225          4.6904
# ...                                              ...             ...
# Venezuela (Bolivarian Republic of)           42.7586          7.5417
# Vietnam                                      39.0364          1.3279
# Yemen                                        46.5455          3.9515
# Zambia                                       46.7081          3.0062
# Zimbabwe                                     46.0759          6.2601
#
#                                     Vegetables
# Country
# Afghanistan                             0.7504
# Albania                                 2.7508
# Algeria                                 2.0457
# Angola                                  0.3525
# Antigua and Barbuda                     1.2960
# ...                                        ...
# Venezuela (Bolivarian Republic of)      0.6674
# Vietnam                                 1.9578
# Yemen                                   0.3636
# Zambia                                  0.4472
# Zimbabwe                                0.2532
#
# [170 rows x 23 columns]

# %%
covid_df= food_supply_df[["Country","Obesity","Undernourished","Confirmed", "Deaths","Recovered", "Active", "Population"]].set_index("Country")
covid_df
# Out:
#                                     Obesity Undernourished  Confirmed  \
# Country
# Afghanistan                             4.5           29.8   0.120684
# Albania                                22.3            6.2   1.399542
# Algeria                                26.6            3.9   0.191816
# Angola                                  6.8             25   0.047103
# Antigua and Barbuda                    19.1            NaN   0.146939
# ...                                     ...            ...        ...
# Venezuela (Bolivarian Republic of)     25.2           21.2   0.359808
# Vietnam                                 2.1            9.3   0.001412
# Yemen                                  14.1           38.9   0.007433
# Zambia                                  6.5           46.7   0.096279
# Zimbabwe                               12.3           51.3   0.068149
#
#                                       Deaths  Recovered    Active  Population
# Country
# Afghanistan                         0.004680   0.095114  0.019903  38928000.0
# Albania                             0.029563   0.701621  0.668358   2838000.0
# Algeria                             0.005555   0.123971  0.062290  44357000.0
# Angola                              0.001079   0.025026  0.020998  32522000.0
# Antigua and Barbuda                 0.004082   0.135714  0.007143     98000.0
# ...                                      ...        ...       ...         ...
# Venezuela (Bolivarian Republic of)  0.003159   0.342224  0.014425  28645000.0
# Vietnam                             0.000036   0.001248  0.000127  96209000.0
# Yemen                               0.002082   0.005090  0.000262  29826000.0
# Zambia                              0.001942   0.092940  0.001398  18384000.0
# Zimbabwe                            0.001864   0.058151  0.008134  14863000.0
#
# [170 rows x 7 columns]

# %%
grains= food_supply_df[["Cereals - Excluding Beer", "Oilcrops", "Spices"]].sum(axis=1)
grains
# Out:
# 0      37.3938
# 1      17.2993
# 2      25.3995
# 3      19.4316
# 4      14.6678
#         ...
# 165    21.3571
# 166    29.2986
# 167    32.2909
# 168    34.8074
# 169    30.5408
# Length: 170, dtype: float64

# %%
vegs=food_supply_df[["Pulses", "Starchy Roots", "Sugar Crops", "Vegetal Products", "Vegetables"]].sum(axis=1)
vegs
# Out:
# 0      46.8235
# 1      38.7320
# 2      49.0368
# 3      59.7929
# 4      37.2145
#         ...
# 165    45.5172
# 166    42.3221
# 167    48.4364
# 168    51.5528
# 169    48.2393
# Length: 170, dtype: float64

# %%
fruits=food_supply_df[["Fruits - Excluding Wine", "Treenuts"]].sum(axis=1)
fruits
# Out:
# 0      1.6008
# 1      4.2954
# 2      3.4045
# 3      2.3133
# 4      3.7647
#         ...
# 165    2.3804
# 166    2.1621
# 167    1.2121
# 168    0.2236
# 169    0.5524
# Length: 170, dtype: float64

# %%
protein=food_supply_df[["Animal Products", "Animal fats", "Aquatic Products, Other", "Meat", "Milk - Excluding Butter", "Offals"]].sum(axis=1)
protein
# Out:
# 0       9.4047
# 1      31.2298
# 2      11.5276
# 3       8.5042
# 4      28.8007
#         ...
# 165    13.7487
# 166    20.6162
# 167     6.5939
# 168     5.8136
# 169     7.5489
# Length: 170, dtype: float64

# %%
misc=food_supply_df[["Miscellaneous", "Stimulants", "Sugar & Sweeteners", "Vegetable Oils", "Alcoholic Beverages"]].sum(axis=1)
misc
# Out:
# 0       4.6273
# 1       7.4875
# 2      10.0941
# 3       9.0770
# 4      13.6186
#         ...
# 165    16.2624
# 166     4.2730
# 167    11.1515
# 168     6.8322
# 169    12.8193
# Length: 170, dtype: float64

# %%
clean_food=pd.DataFrame({'Grains': grains, 'Vegetables':vegs, 'Fruits':fruits, 'Proteins':protein, "Misc":misc})
clean_food
# Out:
#       Grains  Vegetables  Fruits  Proteins     Misc
# 0    37.3938     46.8235  1.6008    9.4047   4.6273
# 1    17.2993     38.7320  4.2954   31.2298   7.4875
# 2    25.3995     49.0368  3.4045   11.5276  10.0941
# 3    19.4316     59.7929  2.3133    8.5042   9.0770
# 4    14.6678     37.2145  3.7647   28.8007  13.6186
# ..       ...         ...     ...       ...      ...
# 165  21.3571     45.5172  2.3804   13.7487  16.2624
# 166  29.2986     42.3221  2.1621   20.6162   4.2730
# 167  32.2909     48.4364  1.2121    6.5939  11.1515
# 168  34.8074     51.5528  0.2236    5.8136   6.8322
# 169  30.5408     48.2393  0.5524    7.5489  12.8193
#
# [170 rows x 5 columns]

# %%
country= food_supply_df[['Country']]
country.join(clean_food).set_index("Country")
# Out:
#                                      Grains  Vegetables  Fruits  Proteins  \
# Country
# Afghanistan                         37.3938     46.8235  1.6008    9.4047
# Albania                             17.2993     38.7320  4.2954   31.2298
# Algeria                             25.3995     49.0368  3.4045   11.5276
# Angola                              19.4316     59.7929  2.3133    8.5042
# Antigua and Barbuda                 14.6678     37.2145  3.7647   28.8007
# ...                                     ...         ...     ...       ...
# Venezuela (Bolivarian Republic of)  21.3571     45.5172  2.3804   13.7487
# Vietnam                             29.2986     42.3221  2.1621   20.6162
# Yemen                               32.2909     48.4364  1.2121    6.5939
# Zambia                              34.8074     51.5528  0.2236    5.8136
# Zimbabwe                            30.5408     48.2393  0.5524    7.5489
#
#                                        Misc
# Country
# Afghanistan                          4.6273
# Albania                              7.4875
# Algeria                             10.0941
# Angola                               9.0770
# Antigua and Barbuda                 13.6186
# ...                                     ...
# Venezuela (Bolivarian Republic of)  16.2624
# Vietnam                              4.2730
# Yemen                               11.1515
# Zambia                               6.8322
# Zimbabwe                            12.8193
#
# [170 rows x 5 columns]
